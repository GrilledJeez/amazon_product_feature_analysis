# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use ('ggplot')

# %% [markdown]
# ### Dataframing & EDA

# %% [markdown]
# This data covers Amazon reviews from 1995-2015. The data is five years old at the youngest, and is an excellent analog to demonstrate product feature identification and prioritization using customer reviews as feedback.
#
# 1. First read in the datasets provided from aws.
#
#
# - Instructions to find and load the data can be found on the [Amazon Customer Reviews Dataset](https://s3.amazonaws.com/amazon-reviews-pds/readme.html) website.
#
# - The data selected represents Amazon's *Kitchen*, *Major Appliances*, and *Home* categories.

# %%
kitch_df = pd.read_csv('amazon_reviews_us_Kitchen_v1_00.tsv.gz', delimiter='\t',encoding='utf-8', error_bad_lines=False)
# Out:
# b'Skipping line 16148: expected 15 fields, saw 22\nSkipping line 20100: expected 15 fields, saw 22\nSkipping line 45178: expected 15 fields, saw 22\nSkipping line 48700: expected 15 fields, saw 22\nSkipping line 63331: expected 15 fields, saw 22\n'
# b'Skipping line 86053: expected 15 fields, saw 22\nSkipping line 88858: expected 15 fields, saw 22\nSkipping line 115017: expected 15 fields, saw 22\n'
# b'Skipping line 137366: expected 15 fields, saw 22\nSkipping line 139110: expected 15 fields, saw 22\nSkipping line 165540: expected 15 fields, saw 22\nSkipping line 171813: expected 15 fields, saw 22\n'
# b'Skipping line 203723: expected 15 fields, saw 22\nSkipping line 209366: expected 15 fields, saw 22\nSkipping line 211310: expected 15 fields, saw 22\nSkipping line 246351: expected 15 fields, saw 22\nSkipping line 252364: expected 15 fields, saw 22\n'
# ...

# %%
kitch_df.info(), 
kitch_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4874890 entries, 0 to 4874889
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   marketplace        object
#  1   customer_id        int64
#  2   review_id          object
#  3   product_id         object
#  4   product_parent     int64
#  5   product_title      object
#  6   product_category   object
#  7   star_rating        float64
#  8   helpful_votes      float64
#  9   total_votes        float64
#  10  vine               object
#  11  verified_purchase  object
#  12  review_headline    object
#  13  review_body        object
#  14  review_date        object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 557.9+ MB
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     37000337  R3DT59XH7HXR9K  B00303FI0G       529320574
# 1          US     15272914  R1LFS11BNASSU8  B00JCZKZN6       274237558
# ...

# %%
kitch_df.to_csv(index=False)

# %%
major_app_df = pd.read_csv('amazon_reviews_us_Major_Appliances_v1_00.tsv.gz', delimiter='\t',encoding='utf-8', error_bad_lines=False)

# %%
major_app_df.to_csv(index=False)

# %%
# home_df = pd.read_csv('amazon_reviews_us_Home_v1_00.tsv.gz', delimiter='\t',encoding='utf-8', error_bad_lines=False)

# %% [markdown]
# Pseudocode / Goals
#
#     - Find all microwaves and ovens with over 500 reviews in each of the Amazon categories
#     -

# %%
kitch_oven = []
kitch_microwave = []
ovens = kitch_df[kitch_df['product_title'].str.contains('convection oven', case=False, na=False)].groupby('product_title').count().marketplace.sort_values(ascending=False)[:5]

# %%
microwaves = kitch_df[kitch_df['product_title'].str.contains('microwave', case=False, na=False)].groupby('product_title').count().marketplace.sort_values(ascending=False)[:1]
# for idx, _ in enumerate(ovens):
#     if _ >= 500:
#         kitch_oven.append(ovens.index[idx])
        
# for idx, _ in enumerate(microwaves):
#     if _ >= 500:
#         kitch_microwave.append(microwaves.index[idx])

# %%
microwaves.head()
# Out:
# product_title
# Panasonic Genius 1250 Watt Sensor Microwave w/Inverter Technology    1875
# Name: marketplace, dtype: int64

# %%
microwave1_df.head()
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 577            US     44300577  R2ZU11YALTJNZX  B0009KMYHI       168831590
# 9061           US     50952586   RVBITZNBVJ8AI  B0009KMYHI       168831590
# 12364          US     31144708   R44LZL0OR5EWP  B0009KMYDM       168831590
# 17084          US     14667788   RPWWYNUD9X64U  B0009KMYHI       168831590
# 18829          US     25468208   RS76DCCGM685B  B0009KMYGY       168831590
#
#                                            product_title product_category  \
# 577    Panasonic Genius 1250 Watt Sensor Microwave w/...          Kitchen
# 9061   Panasonic Genius 1250 Watt Sensor Microwave w/...          Kitchen
# 12364  Panasonic Genius 1250 Watt Sensor Microwave w/...          Kitchen
# 17084  Panasonic Genius 1250 Watt Sensor Microwave w/...          Kitchen
# 18829  Panasonic Genius 1250 Watt Sensor Microwave w/...          Kitchen
#
# ...

# %%
microwave1_df = kitch_df[kitch_df['product_title'].str.contains('Panasonic Genius 1250 Watt Sensor Microwave w/Inverter Technology', case=False, na=False)]

# %%
breville_df.to_csv('oven1_df', index=False)

# %%
microwave1_df.to_csv('microwave1_df', index=False)

# %%
df[df['product_title'].str.contains('Waring Pro TCO650 Digital Convection Oven', case=False, na=False)]
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 5252             US     36328996  R11UXYBBGJGZEM  B005RRBMVW       357820016
# 8587             US     47286148  R1TW1XHBQTTCQE  B005RRBMVW       357820016
# 15996            US     30302830   RNY2YHF237SL4  B005RRBMVW       357820016
# 19615            US     14637566   RSEKMR4GMMMZ0  B005RRBMVW       357820016
# 38128            US     28769289  R3Q7PI0NYV93N8  B005RRBMVW       357820016
# ...             ...          ...             ...         ...             ...
# 3982750          US     14826582  R3O3FWF7914O1S  B005RRBMVW       357820016
# 4002863          US     45074921   RZ60PRK3IHOEA  B005RRBMVW       357820016
# 4015823          US     13459613  R21T7J0LKPNO3L  B005RRBMVW       357820016
# 4022468          US     37990198  R1DUHA5EE9L30E  B005RRBMVW       357820016
# 4052689          US     29997480  R2CD084RRN14Z6  B005RRBMVW       357820016
#
# ...

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     20422322   R8MEA6IGAHO0B  B00MC4CED8       217304173
# 1          US     40835037  R31LOQ8JGLPRLK  B00OQMFG1Q       137313254
# 2          US     51469641  R2Y0MM9YE6OP3P  B00QERR5CY        82850235
# 3          US      4332923   RRB9C05HDOD4O  B00QUFTPV4       221169481
# 4          US     44855305  R26I2RI1GFV8QG  B0067XVNTG       563475445
#
#                                        product_title    product_category  \
# 0                               BlackVue DR600GW-PMP  Mobile_Electronics
# 1  GENSSI GSM / GPS Two Way Smart Phone Car Alarm...  Mobile_Electronics
# 2                    iXCC Multi pack Lightning cable  Mobile_Electronics
# 3  abcGoodefg® FBI Covert Acoustic Tube Earpiece ...  Mobile_Electronics
# 4  Generic Car Dashboard Video Camera Vehicle Vid...  Mobile_Electronics
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# ...

# %%
# df[
# sum(
df[df['product_title'].str.contains('kindle', case=False, na=False) | df['product_title'].str.contains('fire', case=False, na=False)]
#     .astype(bool))
# Out:
#        marketplace  customer_id       review_id  product_id  product_parent  \
# 180             US     19709513  R2KIYLTNUT9ZDZ  B00S008WB6       183355568
# 305             US      9706523  R2MEKKYG0FQ9Y4  B00XNZHWG4       258074372
# 423             US     13659988  R2QS6V8ZE46VBQ  B00R27IK3I        70360668
# 577             US     14054766  R1VUVIY42YJ370  B00SZAXB3U       113311433
# 854             US      2867186  R2YKJOFV6QRFKA  B00GEYZJZC        95521647
# ...            ...          ...             ...         ...             ...
# 103183          US     51131617  R1AMCW1DIRGGVS  B000M9JO4C       877711781
# 103345          US     14573024  R1OJ26UY7OQJUF  B000E440XU       286662707
# 103385          US     49503062   RBD95AHFJAEXZ  B0006ZSZFG       582700261
# 103464          US     12539036   RCTLR3JF78K2U  B000M9JO4C       877711781
# 104384          US     41117501  R3FC6N6ACIICYF  B000CF512A       127917363
#
# ...
